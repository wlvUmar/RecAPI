# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("dataset.csv", nrows=5000)

# %%
df.head()
# Out:
#        id            title  vote_average  vote_count    status release_date  \
# 0   27205        Inception         8.364       34495  Released   2010-07-15
# 1  157336     Interstellar         8.417       32571  Released   2014-11-05
# 2     155  The Dark Knight         8.512       30619  Released   2008-07-16
# 3   19995           Avatar         7.573       29815  Released   2009-12-15
# 4   24428     The Avengers         7.710       29166  Released   2012-04-25
#
#       revenue  runtime  adult                     backdrop_path  ...  \
# 0   825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1   701729206      169  False  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2  1004558444      152  False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3  2923706026      162  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4  1518815515      143  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
#
#                 Star3               Star4             Writer  \
# 0         Elliot Page        Ken Watanabe  Christopher Nolan
# 1    Jessica Chastain       Mackenzie Foy     Jonathan Nolan
# 2       Aaron Eckhart       Michael Caine     Jonathan Nolan
# 3    Sigourney Weaver  Michelle Rodriguez      James Cameron
# 4  Scarlett Johansson       Jeremy Renner      Sydney Newman
#
#   Director_of_Photography                                          Producers  \
# 0           Wally Pfister  Thomas Tull, Christopher Nolan, Chris Brigham,...
# 1       Hoyte van Hoytema  Jake Myers, Emma Thomas, Jordan Goldberg, Thom...
# 2           Wally Pfister  Kevin De La Noy, Thomas Tull, Christopher Nola...
# 3             Mauro Fiore  Jon Landau, Colin Wilson, Laeta Kalogridis, Ja...
# 4                     NaN                                                NaN
#
#                      Music_Composer  \
# 0                       Hans Zimmer
# 1                       Hans Zimmer
# 2  Hans Zimmer, James Newton Howard
# 3                      James Horner
# 4                               NaN
#
#                                          genres_list  \
# 0         ['Action', 'Science Fiction', 'Adventure']
# 1          ['Adventure', 'Drama', 'Science Fiction']
# 2           ['Drama', 'Action', 'Crime', 'Thriller']
# 3  ['Action', 'Adventure', 'Fantasy', 'Science Fi...
# 4         ['Science Fiction', 'Action', 'Adventure']
#
#                                            Cast_list overview_sentiment  \
# 0  ['Tim Kelleher', 'Silvie Laguna', 'Natasha Bea...          -0.011111
# 1  ['Jeff Hephner', 'William Devane', 'Elyes Gabe...           0.045455
# 2  ['Tommy Lister Jr.', 'Edison Chen', 'Beatrice ...           0.025000
# 3  ['Carvon Futrell', 'Joel David Moore', 'Jon Cu...           0.041667
# 4  ['Haneyuri', 'Nako Mizusawa', 'Marin', 'Rikako...           0.025000
#
#                                all_combined_keywords
# 0  ['s', 'philosophy', 'skilled', 'kidnapping', '...
# 1  ['thoughtful', 'use', 'scientist', 'quantum me...
# 2  ['reign', 'harvey', 'proves', 'partnership', '...
# 3  ['space war', 'civilization', 'society', 'mari...
# 4  ['s', 'world', 'begins', 'e', 'global safety',...
#
# [5 rows x 42 columns]

# %%
df
# Out:
#           id                        title  vote_average  vote_count    status  \
# 0      27205                    Inception         8.364       34495  Released
# 1     157336                 Interstellar         8.417       32571  Released
# 2        155              The Dark Knight         8.512       30619  Released
# 3      19995                       Avatar         7.573       29815  Released
# 4      24428                 The Avengers         7.710       29166  Released
# ...      ...                          ...           ...         ...       ...
# 4995  831405                    Injustice         7.466         714  Released
# 4996  659959                 Summer of 85         7.408         714  Released
# 4997  175574                   Free Birds         5.862         714  Released
# 4998    4787            Cassandra's Dream         6.244         714  Released
# 4999  522478  Peter Rabbit 2: The Runaway         7.171         714  Released
#
#      release_date     revenue  runtime  adult  \
# 0      2010-07-15   825532764      148  False
# 1      2014-11-05   701729206      169  False
# 2      2008-07-16  1004558444      152  False
# 3      2009-12-15  2923706026      162  False
# 4      2012-04-25  1518815515      143  False
# ...           ...         ...      ...    ...
# 4995   2021-10-09           0       78  False
# 4996   2020-07-14     3600000      101  False
# 4997   2013-10-30   110000000       91  False
# 4998   2007-06-18    22687639      108  False
# 4999   2021-03-25   153000000       93  False
#
#                          backdrop_path  ...               Star3  \
# 0     /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...         Elliot Page
# 1     /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...    Jessica Chastain
# 2     /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...       Aaron Eckhart
# 3     /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...    Sigourney Weaver
# 4     /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...  Scarlett Johansson
# ...                                ...  ...                 ...
# 4995  /q4h2ZbhHKhnWvrrqzcjT778zlbn.jpg  ...                 NaN
# 4996  /oq1AkrBDj8hRVJqC2NDFT5R1NEa.jpg  ...                 NaN
# 4997  /bYCYL5mVX4unStJy34wWuofVq2O.jpg  ...                 NaN
# 4998  /5Xb2e63jvhJqL6IUO2SqtuRIJRG.jpg  ...                 NaN
# 4999  /5HjzYTihkH7EvOWSE7KcsF6pBMM.jpg  ...                 NaN
#
#                    Star4             Writer Director_of_Photography  \
# 0           Ken Watanabe  Christopher Nolan           Wally Pfister
# 1          Mackenzie Foy     Jonathan Nolan       Hoyte van Hoytema
# 2          Michael Caine     Jonathan Nolan           Wally Pfister
# 3     Michelle Rodriguez      James Cameron             Mauro Fiore
# 4          Jeremy Renner      Sydney Newman                     NaN
# ...                  ...                ...                     ...
# 4995                 NaN       Stephen Dyer          Jarin Blaschke
# 4996                 NaN  Nicole Holofcener                     NaN
# 4997                 NaN        Doug Taylor           Emilio Vigara
# 4998                 NaN      Billy Crystal                     NaN
# 4999                 NaN        James Bobin                     NaN
#
#                                               Producers  \
# 0     Thomas Tull, Christopher Nolan, Chris Brigham,...
# 1     Jake Myers, Emma Thomas, Jordan Goldberg, Thom...
# 2     Kevin De La Noy, Thomas Tull, Christopher Nola...
# 3     Jon Landau, Colin Wilson, Laeta Kalogridis, Ja...
# 4                                                   NaN
# ...                                                 ...
# 4995                                       Jodi Redmond
# 4996                                                NaN
# 4997                                                NaN
# 4998    Jiang Ping, Chen Gong-De, Liu Jun, Vash Yan Jia
# 4999                                                NaN
#
#                         Music_Composer  \
# 0                          Hans Zimmer
# 1                          Hans Zimmer
# 2     Hans Zimmer, James Newton Howard
# 3                         James Horner
# 4                                  NaN
# ...                                ...
# 4995                               NaN
# 4996                               NaN
# 4997                      Tomás Virgós
# 4998                               NaN
# 4999                               NaN
#
#                                             genres_list  \
# 0            ['Action', 'Science Fiction', 'Adventure']
# 1             ['Adventure', 'Drama', 'Science Fiction']
# 2              ['Drama', 'Action', 'Crime', 'Thriller']
# 3     ['Action', 'Adventure', 'Fantasy', 'Science Fi...
# 4            ['Science Fiction', 'Action', 'Adventure']
# ...                                                 ...
# 4995  ['Animation', 'Science Fiction', 'Fantasy', 'A...
# 4996                               ['Romance', 'Drama']
# 4997                  ['Animation', 'Comedy', 'Family']
# 4998                     ['Crime', 'Drama', 'Thriller']
# 4999  ['Family', 'Comedy', 'Adventure', 'Animation',...
#
#                                               Cast_list overview_sentiment  \
# 0     ['Tim Kelleher', 'Silvie Laguna', 'Natasha Bea...          -0.011111
# 1     ['Jeff Hephner', 'William Devane', 'Elyes Gabe...           0.045455
# 2     ['Tommy Lister Jr.', 'Edison Chen', 'Beatrice ...           0.025000
# 3     ['Carvon Futrell', 'Joel David Moore', 'Jon Cu...           0.041667
# 4     ['Haneyuri', 'Nako Mizusawa', 'Marin', 'Rikako...           0.025000
# ...                                                 ...                ...
# 4995  ['Griffen Fox Smith', 'Beth Brown', 'Ethan Sai...          -0.200000
# 4996                                ['Antonio Daniele']           0.220000
# 4997  ['Luis Miguel Díez', 'Pablo Arbúes', 'Eduardo ...           0.233333
# 4998  ['Peter Ho', 'Yang Qiming', 'Li Dongxue', 'Xia...          -0.258333
# 4999  ['Divna Jovanović', 'Zoran Stojiljković', "Mih...          -0.033333
#
#                                   all_combined_keywords
# 0     ['s', 'philosophy', 'skilled', 'kidnapping', '...
# 1     ['thoughtful', 'use', 'scientist', 'quantum me...
# 2     ['reign', 'harvey', 'proves', 'partnership', '...
# 3     ['space war', 'civilization', 'society', 'mari...
# 4     ['s', 'world', 'begins', 'e', 'global safety',...
# ...                                                 ...
# 4995  ['world', 'batman', 'lois', 'fighting', 'survi...
# 4996  ['s', 'grew', 'pact', 'just', 'lifelong', 'bes...
# 4997  ['holiday', 'sides', 'tracks', 'time', 'opposi...
# 4998  ['despair', 'turn', 'crime', 'serious financia...
# 4999  ['peter rabbit', 'soon', 'away', 'learns', 'li...
#
# [5000 rows x 42 columns]

# %%
needed_cols = [
    'id', 'title', 'overview', 'genres_list', 'all_combined_keywords',
    'release_year', 'Director', 'Cast_list'
]

df = df[needed_cols]
df = df.drop_duplicates(subset=['title'])

# %%
df.head()
# Out:
#        id            title                                           overview  \
# 0   27205        Inception  Cobb, a skilled thief who commits corporate es...
# 1  157336     Interstellar  The adventures of a group of explorers who mak...
# 2     155  The Dark Knight  Batman raises the stakes in his war on crime. ...
# 3   19995           Avatar  In the 22nd century, a paraplegic Marine is di...
# 4   24428     The Avengers  When an unexpected enemy emerges and threatens...
#
#                                          genres_list  \
# 0         ['Action', 'Science Fiction', 'Adventure']
# 1          ['Adventure', 'Drama', 'Science Fiction']
# 2           ['Drama', 'Action', 'Crime', 'Thriller']
# 3  ['Action', 'Adventure', 'Fantasy', 'Science Fi...
# 4         ['Science Fiction', 'Action', 'Adventure']
#
#                                all_combined_keywords  release_year  \
# 0  ['s', 'philosophy', 'skilled', 'kidnapping', '...        2010.0
# 1  ['thoughtful', 'use', 'scientist', 'quantum me...        2014.0
# 2  ['reign', 'harvey', 'proves', 'partnership', '...        2008.0
# 3  ['space war', 'civilization', 'society', 'mari...        2009.0
# 4  ['s', 'world', 'begins', 'e', 'global safety',...        2012.0
#
#             Director                                          Cast_list
# 0  Christopher Nolan  ['Tim Kelleher', 'Silvie Laguna', 'Natasha Bea...
# 1  Christopher Nolan  ['Jeff Hephner', 'William Devane', 'Elyes Gabe...
# 2  Christopher Nolan  ['Tommy Lister Jr.', 'Edison Chen', 'Beatrice ...
# 3      James Cameron  ['Carvon Futrell', 'Joel David Moore', 'Jon Cu...
# 4        Joss Whedon  ['Haneyuri', 'Nako Mizusawa', 'Marin', 'Rikako...

# %%
df.rename(columns={
    'overview': 'description',
    'genres_list': 'genres',
    'all_combined_keywords': 'tags',
    'Director': 'director',
    'Cast_list': 'actors'
}, inplace=True)

# %%
df['description'] = df['description'].fillna("")
df['director'] = df['director'].fillna("")

# %%
df.to_csv("processed_movies.csv", index=False)

# %%
pd.read_csv("processed_movies.csv")
# Out:
#           id                        title  \
# 0      27205                    Inception
# 1     157336                 Interstellar
# 2        155              The Dark Knight
# 3      19995                       Avatar
# 4      24428                 The Avengers
# ...      ...                          ...
# 4881  831405                    Injustice
# 4882  659959                 Summer of 85
# 4883  175574                   Free Birds
# 4884    4787            Cassandra's Dream
# 4885  522478  Peter Rabbit 2: The Runaway
#
#                                             description  \
# 0     Cobb, a skilled thief who commits corporate es...
# 1     The adventures of a group of explorers who mak...
# 2     Batman raises the stakes in his war on crime. ...
# 3     In the 22nd century, a paraplegic Marine is di...
# 4     When an unexpected enemy emerges and threatens...
# ...                                                 ...
# 4881  When Lois Lane is killed, an unhinged Superman...
# 4882  What do you dream of when you're 16-years-old ...
# 4883  Two turkeys from opposite sides of the tracks ...
# 4884  The tale of two brothers with serious financia...
# 4885  Peter Rabbit runs away from his human family w...
#
#                                                  genres  \
# 0            ['Action', 'Science Fiction', 'Adventure']
# 1             ['Adventure', 'Drama', 'Science Fiction']
# 2              ['Drama', 'Action', 'Crime', 'Thriller']
# 3     ['Action', 'Adventure', 'Fantasy', 'Science Fi...
# 4            ['Science Fiction', 'Action', 'Adventure']
# ...                                                 ...
# 4881  ['Animation', 'Science Fiction', 'Fantasy', 'A...
# 4882                               ['Romance', 'Drama']
# 4883                  ['Animation', 'Comedy', 'Family']
# 4884                     ['Crime', 'Drama', 'Thriller']
# 4885  ['Family', 'Comedy', 'Adventure', 'Animation',...
#
#                                                    tags  release_year  \
# 0     ['s', 'philosophy', 'skilled', 'kidnapping', '...        2010.0
# 1     ['thoughtful', 'use', 'scientist', 'quantum me...        2014.0
# 2     ['reign', 'harvey', 'proves', 'partnership', '...        2008.0
# 3     ['space war', 'civilization', 'society', 'mari...        2009.0
# 4     ['s', 'world', 'begins', 'e', 'global safety',...        2012.0
# ...                                                 ...           ...
# 4881  ['world', 'batman', 'lois', 'fighting', 'survi...        2021.0
# 4882  ['s', 'grew', 'pact', 'just', 'lifelong', 'bes...        2020.0
# 4883  ['holiday', 'sides', 'tracks', 'time', 'opposi...        2013.0
# 4884  ['despair', 'turn', 'crime', 'serious financia...        2007.0
# 4885  ['peter rabbit', 'soon', 'away', 'learns', 'li...        2021.0
#
#                director                                             actors
# 0     Christopher Nolan  ['Tim Kelleher', 'Silvie Laguna', 'Natasha Bea...
# 1     Christopher Nolan  ['Jeff Hephner', 'William Devane', 'Elyes Gabe...
# 2     Christopher Nolan  ['Tommy Lister Jr.', 'Edison Chen', 'Beatrice ...
# 3         James Cameron  ['Carvon Futrell', 'Joel David Moore', 'Jon Cu...
# 4           Joss Whedon  ['Haneyuri', 'Nako Mizusawa', 'Marin', 'Rikako...
# ...                 ...                                                ...
# 4881       Tanya Wexler  ['Griffen Fox Smith', 'Beth Brown', 'Ethan Sai...
# 4882  Nicole Holofcener                                ['Antonio Daniele']
# 4883           Uwe Boll  ['Luis Miguel Díez', 'Pablo Arbúes', 'Eduardo ...
# 4884           Joe Roth  ['Peter Ho', 'Yang Qiming', 'Li Dongxue', 'Xia...
# 4885     Randal Kleiser  ['Divna Jovanović', 'Zoran Stojiljković', "Mih...
#
# [4886 rows x 8 columns]
